# %%
env_content = """
POSTGRES_USER=postgres
POSTGRES_PASSWORD=
POSTGRES_HOST=localhost
POSTGRES_PORT=
POSTGRES_DB=

SQLITE_DB_PATH=
"""

with open(".env", "w") as file:
    file.write(env_content)

print(".env file created successfully")
# Out:
# .env file created successfully

# %%
import os

print(os.listdir())
# Out:
# ['.env', '.ipynb_checkpoints', 'Creating_environment_variable.ipynb', 'inventory.db']
